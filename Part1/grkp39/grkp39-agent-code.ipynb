# %% [markdown]
# # Coursework Template

# %% [markdown]
# **Dependencies and imports**
#
# This can take a minute...

# %%
# !pip install swig
# !pip install --upgrade rldurham
# !pip install pillow==10.0.0
# Out:
# Requirement already satisfied: swig in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (4.3.0)
# Requirement already up-to-date: rldurham in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied, skipping upgrade: scipy in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (1.13.1)
# Requirement already satisfied, skipping upgrade: lightning in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (2.5.0.post0)
# Requirement already satisfied, skipping upgrade: requests in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (2.32.3)
# Requirement already satisfied, skipping upgrade: torch in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (2.5.0)
# Requirement already satisfied, skipping upgrade: IPython in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (8.18.1)
# Requirement already satisfied, skipping upgrade: gymnasium[atari,box2d,other] in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (1.1.0)
# Requirement already satisfied, skipping upgrade: ipywidgets in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (8.1.5)
# Requirement already satisfied, skipping upgrade: numpy in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (1.26.4)
# Requirement already satisfied, skipping upgrade: pandas in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from rldurham) (2.2.3)
# Requirement already satisfied, skipping upgrade: fsspec[http]<2026.0,>=2022.5.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (2024.9.0)
# Requirement already satisfied, skipping upgrade: lightning-utilities<2.0,>=0.10.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (0.12.0)
# Requirement already satisfied, skipping upgrade: packaging<25.0,>=20.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (24.1)
# Requirement already satisfied, skipping upgrade: typing-extensions<6.0,>=4.4.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (4.12.2)
# Requirement already satisfied, skipping upgrade: tqdm<6.0,>=4.57.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (4.67.1)
# Requirement already satisfied, skipping upgrade: pytorch-lightning in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (2.5.0.post0)
# Requirement already satisfied, skipping upgrade: PyYAML<8.0,>=5.4 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (6.0.2)
# Requirement already satisfied, skipping upgrade: torchmetrics<3.0,>=0.7.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning->rldurham) (1.6.2)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from requests->rldurham) (2.2.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from requests->rldurham) (2024.8.30)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from requests->rldurham) (3.10)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from requests->rldurham) (3.4.0)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (11.2.1.3)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu12==2.21.5; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (2.21.5)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (11.6.1.9)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.127)
# Requirement already satisfied, skipping upgrade: jinja2 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (3.1.4)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.127)
# Requirement already satisfied, skipping upgrade: sympy==1.13.1; python_version >= "3.9" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (1.13.1)
# Requirement already satisfied, skipping upgrade: triton==3.1.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (3.1.0)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.127)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.127)
# Requirement already satisfied, skipping upgrade: filelock in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (3.16.1)
# Requirement already satisfied, skipping upgrade: networkx in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (3.2.1)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (9.1.0.70)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (10.3.5.147)
# Requirement already satisfied, skipping upgrade: nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.127)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.4.5.8)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from torch->rldurham) (12.3.1.170)
# Requirement already satisfied, skipping upgrade: exceptiongroup; python_version < "3.11" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (1.2.2)
# Requirement already satisfied, skipping upgrade: jedi>=0.16 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (0.19.1)
# Requirement already satisfied, skipping upgrade: pygments>=2.4.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (2.18.0)
# Requirement already satisfied, skipping upgrade: traitlets>=5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (5.14.3)
# Requirement already satisfied, skipping upgrade: decorator in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (5.1.1)
# Requirement already satisfied, skipping upgrade: pexpect>4.3; sys_platform != "win32" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (4.9.0)
# Requirement already satisfied, skipping upgrade: matplotlib-inline in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (0.1.7)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<3.1.0,>=3.0.41 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (3.0.48)
# Requirement already satisfied, skipping upgrade: stack-data in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from IPython->rldurham) (0.6.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=4.8.0; python_version < "3.10" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (8.5.0)
# Requirement already satisfied, skipping upgrade: farama-notifications>=0.0.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (0.0.4)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.2.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (3.1.1)
# Requirement already satisfied, skipping upgrade: ale_py>=0.9; extra == "atari" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (0.10.2)
# Requirement already satisfied, skipping upgrade: box2d-py==2.3.5; extra == "box2d" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (2.3.5)
# Requirement already satisfied, skipping upgrade: pygame>=2.1.3; extra == "box2d" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (2.6.1)
# Requirement already satisfied, skipping upgrade: swig==4.*; extra == "box2d" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (4.3.0)
# Requirement already satisfied, skipping upgrade: seaborn>=0.13; extra == "other" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (0.13.2)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0; extra == "other" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (3.8.1)
# Requirement already satisfied, skipping upgrade: moviepy>=1.0.0; extra == "other" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (2.1.2)
# Requirement already satisfied, skipping upgrade: opencv-python>=3.0; extra == "other" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from gymnasium[atari,box2d,other]->rldurham) (4.11.0.86)
# Requirement already satisfied, skipping upgrade: jupyterlab-widgets~=3.0.12 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from ipywidgets->rldurham) (3.0.13)
# Requirement already satisfied, skipping upgrade: comm>=0.1.3 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from ipywidgets->rldurham) (0.2.2)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=4.0.12 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from ipywidgets->rldurham) (4.0.13)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from pandas->rldurham) (2024.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.2 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from pandas->rldurham) (2.9.0.post0)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.7 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from pandas->rldurham) (2024.2)
# Requirement already satisfied, skipping upgrade: aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (3.11.13)
# Requirement already satisfied, skipping upgrade: setuptools in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->rldurham) (44.0.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from jinja2->torch->rldurham) (3.0.1)
# Requirement already satisfied, skipping upgrade: mpmath<1.4,>=1.1.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from sympy==1.13.1; python_version >= "3.9"->torch->rldurham) (1.3.0)
# Requirement already satisfied, skipping upgrade: parso<0.9.0,>=0.8.3 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from jedi>=0.16->IPython->rldurham) (0.8.4)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython->rldurham) (0.7.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->rldurham) (0.2.13)
# Requirement already satisfied, skipping upgrade: executing>=1.2.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from stack-data->IPython->rldurham) (2.1.0)
# Requirement already satisfied, skipping upgrade: asttokens>=2.1.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from stack-data->IPython->rldurham) (2.4.1)
# Requirement already satisfied, skipping upgrade: pure-eval in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from stack-data->IPython->rldurham) (0.2.3)
# Requirement already satisfied, skipping upgrade: zipp>=3.20 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from importlib-metadata>=4.8.0; python_version < "3.10"->gymnasium[atari,box2d,other]->rldurham) (3.20.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (0.12.1)
# Requirement already satisfied, skipping upgrade: pillow>=8 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (10.0.0)
# Requirement already satisfied, skipping upgrade: importlib-resources>=3.2.0; python_version < "3.10" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (6.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.3.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (1.4.7)
# Requirement already satisfied, skipping upgrade: contourpy>=1.0.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (1.3.0)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (4.54.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.3.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from matplotlib>=3.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (3.1.4)
# Requirement already satisfied, skipping upgrade: imageio<3.0,>=2.5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from moviepy>=1.0.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (2.37.0)
# Requirement already satisfied, skipping upgrade: imageio_ffmpeg>=0.2.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from moviepy>=1.0.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (0.6.0)
# Requirement already satisfied, skipping upgrade: python-dotenv>=0.10 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from moviepy>=1.0.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (1.0.1)
# Requirement already satisfied, skipping upgrade: proglog<=1.0.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from moviepy>=1.0.0; extra == "other"->gymnasium[atari,box2d,other]->rldurham) (0.1.10)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->rldurham) (1.16.0)
# Requirement already satisfied, skipping upgrade: aiohappyeyeballs>=2.3.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (2.4.8)
# Requirement already satisfied, skipping upgrade: propcache>=0.2.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (0.3.0)
# Requirement already satisfied, skipping upgrade: frozenlist>=1.1.1 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (1.5.0)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.17.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (1.18.3)
# Requirement already satisfied, skipping upgrade: aiosignal>=1.1.2 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (1.3.2)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (24.2.0)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (6.1.0)
# Requirement already satisfied, skipping upgrade: async-timeout<6.0,>=4.0; python_version < "3.11" in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]<2026.0,>=2022.5.0->lightning->rldurham) (5.0.1)
# Requirement already satisfied: pillow==10.0.0 in /home2/grkp39/myjupyterenv/lib/python3.9/site-packages (10.0.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import rldurham as rld

# %% [markdown]
# **Reinforcement learning agent**
#
# Replace this with your own agent, I recommend starting with TD3 (lecture 8).

# %%
# Device configuration
device = torch.device("cpu")  # Set to GPU if available

# Hyperparameters
GAMMA = 0.99
TAU = 0.005
POLICY_NOISE = 0.2
NOISE_CLIP = 0.5
LEARNING_RATE = 3e-4
BATCH_SIZE = 64
MAX_BUFFER_SIZE = int(1e6)

# Replay Buffer
class ReplayBuffer:
    def __init__(self, state_dim, action_dim, max_size=MAX_BUFFER_SIZE):
        self.max_size = max_size
        self.size = 0
        self.ptr = 0
        self.state = np.zeros((max_size, state_dim))
        self.action = np.zeros((max_size, action_dim))
        self.reward = np.zeros((max_size, 1))
        self.next_state = np.zeros((max_size, state_dim))
        self.not_done = np.zeros((max_size, 1))

    def __len__(self):
        return self.size  # Return the current size of the buffer

    def add(self, state, action, reward, next_state, done):
        index = self.ptr % self.max_size
        self.state[index] = state
        self.action[index] = action
        self.reward[index] = reward
        self.next_state[index] = next_state
        self.not_done[index] = 1.0 - done
        self.ptr += 1
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        indices = np.random.randint(0, self.size, size=batch_size)
        return (
            torch.FloatTensor(self.state[indices]).to(device),
            torch.FloatTensor(self.next_state[indices]).to(device),
            torch.FloatTensor(self.action[indices]).to(device),
            torch.FloatTensor(self.reward[indices]).to(device),
            torch.FloatTensor(self.not_done[indices]).to(device)
        )


# Actor Network
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, action_dim),
            nn.Tanh()
        )
        self.max_action = max_action

    def forward(self, state):
        return self.max_action * self.net(state)

# Critic Network
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()
        self.q1 = nn.Sequential(
            nn.Linear(state_dim + action_dim, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )
        self.q2 = nn.Sequential(
            nn.Linear(state_dim + action_dim, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )

    def forward(self, state, action):
        state_action = torch.cat([state, action], dim=1)
        return self.q1(state_action), self.q2(state_action)

# TD3 Agent
class TD3Agent:
    def __init__(self, state_dim, action_dim, max_action):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LEARNING_RATE)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = Critic(state_dim, action_dim).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LEARNING_RATE)

        self.replay_buffer = ReplayBuffer(state_dim, action_dim)
        self.max_action = max_action

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def update(self, batch_size):
        state, next_state, action, reward, not_done = self.replay_buffer.sample(batch_size)

    # Critic Update
        with torch.no_grad():
            noise = torch.randn_like(action) * POLICY_NOISE
            noise = noise.clamp(-NOISE_CLIP, NOISE_CLIP)
            next_action = (self.actor_target(next_state) + noise).clamp(-self.max_action, self.max_action)
            target_q1, target_q2 = self.critic_target(next_state, next_action)
            target_q = reward + not_done * GAMMA * torch.min(target_q1, target_q2)

        current_q1, current_q2 = self.critic(state, action)
        critic_loss = nn.MSELoss()(current_q1, target_q) + nn.MSELoss()(current_q2, target_q)

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

    # Delayed policy update
        if batch_size % 2 == 0:
            action = self.actor(state)
            q1, _ = self.critic(state, action)
            actor_loss = -q1.mean()

            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(TAU * param.data + (1.0 - TAU) * target_param.data)
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(TAU * param.data + (1.0 - TAU) * target_param.data)

# %% [markdown]
# **Prepare the environment and wrap it to capture statistics, logs, and videos**

# %%
env = rld.make("rldurham/Walker", render_mode="rgb_array")
# env = rld.make("rldurham/Walker", render_mode="rgb_array", hardcore=True) # only attempt this when your agent has solved the non-hardcore version

# get statistics, logs, and videos
env = rld.Recorder(
    env,
    smoothing=10,             # track rolling averages (useful for plotting)
    video=True,              # enable recording videos
    video_folder="videos",        # folder for videos
    video_prefix="grkp39-agent-video",  # prefix for videos (replace xxxx00 with your username)
    logs=True,              # keep logs
)

# training on CPU recommended
rld.check_device()

# environment info
discrete_act, discrete_obs, act_dim, obs_dim = rld.env_info(env, print_out=True)

# render start image
env.reset(seed=42)
rld.render(env)
# Out:
# The device is: cpu (as recommended)
# actions are continuous with 4 dimensions/#actions
# observations are continuous with 24 dimensions/#observations
# maximum timesteps is: None

# %%
# in the submission please use seed_everything with seed 42 for verification
seed, observation, info = rld.seed_everything(42, env)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# initialise agent
agent = TD3Agent(state_dim, action_dim, max_action)
max_episodes = 1500
max_timesteps = 2000

# track statistics for plotting
tracker = rld.InfoTracker()

# switch video recording off (only switch on every x episodes as this is slow)
env.video = True

# training procedure
for episode in range(max_episodes):

    # recording statistics and video can be switched on and off (video recording is slow!)
    # env.info = episode % 10 == 0   # track every x episodes (usually tracking every episode is fine)
    # env.video = episode % 10 == 0  # record videos every x episodes (set BEFORE calling reset!)

    # reset for new episode
    observation, info = env.reset()

    # run episode
    for t in range(max_timesteps):

        # select the agent action
        action = agent.select_action(observation)

        # take action in the environment
        next_observation, reward, terminated, truncated, info = env.step(action)

        # check whether done
        done = terminated or truncated

        # remember
        agent.replay_buffer.add(observation, action, reward, next_observation, done)

        # TRAIN THE AGENT HERE!
        if len(agent.replay_buffer) > BATCH_SIZE:
            agent.update(BATCH_SIZE)

        # 更新当前状态
        observation = next_observation

        # stop episode
        if done:
            break

    # track and plot statistics
    tracker.track(info)
    if (episode + 1) % 10 == 0:
        tracker.plot(r_mean_=True, r_std_=True, r_sum=dict(linestyle=':', marker='x'))

# don't forget to close environment (e.g. triggers last video save)
env.close()

# write log file (for coursework)
env.write_log(folder="logs", file="grkp39-agent-log.txt")  # replace xxxx00 with your username

# %% [markdown]
# A small demo with a predefined heuristic that is suboptimal and has no notion of balance (and is designed for the orignal BipedalWalker environment)...

# %%
from gymnasium.envs.box2d.bipedal_walker import BipedalWalkerHeuristics

env = rld.make(
    "rldurham/Walker",
    # "BipedalWalker-v3",
    render_mode="human",
    # render_mode="rgb_array",
    hardcore=False,
    # hardcore=True,
)
_, obs, info = rld.seed_everything(42, env)

heuristics = BipedalWalkerHeuristics()

act = heuristics.step_heuristic(obs)
for _ in range(500):
    obs, rew, terminated, truncated, info = env.step(act)
    act = heuristics.step_heuristic(obs)
    if terminated or truncated:
        break
    if env.render_mode == "rgb_array":
        rld.render(env, clear=True)
env.close()
# Out:
# [rank: 0] Seed set to 42
